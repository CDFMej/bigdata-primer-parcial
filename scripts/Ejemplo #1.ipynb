# %%
import pandas as pd

datos = {
    "sensor": ["HN-001", "HN-002", "HN-003", "HN-004"],
    "temperatura": [30.5, 31.2, None, 999],
    "humedad": [70, 75, 80, 65]
}

#print(type(datos))
df = pd.DataFrame(datos)

#print(type(df))

#print(df)

print("Promedio de temperatura:")
#print(type(df["temperatura"].mean()))

print(df["temperatura"].mean())

print("Registros con temperatura mayor a 31:")
print(df[df["temperatura"] > 31])
# Out:
# Promedio de temperatura:
# 353.56666666666666
# Registros con temperatura mayor a 31:
#    sensor  temperatura  humedad
# 1  HN-002         31.2       75
# 3  HN-004        999.0       65
